# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import sidetable
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
df_da = pd.read_csv('../data/df_da.csv', index_col = 'index')
pd.options.display.max_columns = None
df_da.sample(4)
# Out:
#          age gender    country          education              role  \
# index
# 185    18-21    Man     Brazil  Bachelor’s degree      Data Analyst
# 3645   60-69    Man     Norway    Doctoral degree  Business Analyst
# 12140  40-44    Man      India  Bachelor’s degree  Business Analyst
# 11812  25-29    Man  Argentina    Master’s degree      Data Analyst
#
#                     prog_language  \
# index
# 185    Python, SQL, C, Javascript
# 3645                Python, Julia
# 12140            Python, SQL, C++
# 11812                 Python, SQL
#
#                                                 code_env    notebook_kaggle  \
# index
# 185    JupyterLab ,Visual Studio Code (VSCode) ,Jupyt...   Kaggle Notebooks
# 3645   JupyterLab ,Visual Studio Code (VSCode) ,PyCha...   Kaggle Notebooks
# 12140  JupyterLab , Spyder, Notepad++, Vim / Emacs,Ju...                NaN
# 11812      Visual Studio Code (VSCode) ,Jupyter Notebook                NaN
#
#         notebook_colab   notebook_azure notebook_paperspace notebook_binder  \
# index
# 185    Colab Notebooks              NaN                 NaN             NaN
# 3645   Colab Notebooks              NaN                 NaN             NaN
# 12140              NaN  Azure Notebooks                 NaN             NaN
# 11812  Colab Notebooks              NaN                 NaN             NaN
#
#       notebook_codeocean notebook_ibmwatsonstudio notebook_amazonsagemaker  \
# index
# 185                  NaN                      NaN                      NaN
# 3645                 NaN                      NaN                      NaN
# 12140                NaN                      NaN                      NaN
# 11812                NaN                      NaN                      NaN
#
#       notebook_amazonemr notebook_googlecloudnotebooks  \
# index
# 185                  NaN                           NaN
# 3645                 NaN                           NaN
# 12140                NaN                           NaN
# 11812                NaN                           NaN
#
#       notebook_googleclouddatalab                   notebook_databricks  \
# index
# 185          Google Cloud Datalab   Databricks Collaborative Notebooks
# 3645                          NaN                                   NaN
# 12140                         NaN                                   NaN
# 11812                         NaN                                   NaN
#
#       notebook_zeppelin     notebook_deepnote notebook_observable  \
# index
# 185                 NaN                   NaN                 NaN
# 3645                NaN                   NaN                 NaN
# 12140               NaN                   NaN                 NaN
# 11812               NaN   Deepnote Notebooks                  NaN
#
#       notebook_OTHER                                             viz  \
# index
# 185              NaN                Matplotlib ,Seaborn ,Geoplotlib
# 3645             NaN   Matplotlib ,Seaborn ,Plotly / Plotly Express
# 12140            NaN   Matplotlib ,Seaborn ,Plotly / Plotly Express
# 11812            NaN                            Matplotlib ,Seaborn
#
#                                       field           salary learn_dp_MySQL  \
# index
# 185    Online Business/Internet-based Sales      5,000-7,499            NaN
# 3645              Manufacturing/Fabrication  125,000-149,999            NaN
# 12140                  Computers/Technology              NaN            NaN
# 11812               Shipping/Transportation      4,000-4,999            NaN
#
#       learn_dp_PostgreSQL learn_dp_SQLite learn_dp_Oracle learn_dp_Mongo  \
# index
# 185                   NaN             NaN             NaN            NaN
# 3645                  NaN             NaN             NaN            NaN
# 12140                 NaN             NaN             NaN            NaN
# 11812                 NaN             NaN             NaN            NaN
#
#       learn_dp_Snowflake learn_dp_IBMDd2 learn_dp_SQLServer learn_dp_AzureSQL  \
# index
# 185                  NaN             NaN                NaN               NaN
# 3645                 NaN             NaN                NaN               NaN
# 12140                NaN             NaN                NaN               NaN
# 11812                NaN             NaN                NaN               NaN
#
#       learn_dp_AzureCosmos learn_dp_Redshift learn_dp_Aurora learn_dp_RDS  \
# index
# 185                    NaN               NaN             NaN          NaN
# 3645                   NaN               NaN             NaN          NaN
# 12140                  NaN               NaN             NaN          NaN
# 11812                  NaN               NaN             NaN          NaN
#
#       learn_dp_DynamoDB learn_dp_BigQuery learn_dp_CloudSQL  \
# index
# 185                 NaN               NaN               NaN
# 3645                NaN               NaN               NaN
# 12140               NaN               NaN               NaN
# 11812               NaN               NaN               NaN
#
#       learn_dp_Firestore learn_dp_BigTable learn_dp_Spanner learn_dp_Other  \
# index
# 185                  NaN               NaN              NaN            NaN
# 3645                 NaN               NaN              NaN            NaN
# 12140                NaN               NaN              NaN            NaN
# 11812                NaN               NaN              NaN            NaN
#
#       dp_most_freq BI_tools share_plotlydash share_streamlit share_NBViewer  \
# index
# 185     Snowflake       NaN              NaN             NaN            NaN
# 3645        MySQL       NaN              NaN      Streamlit             NaN
# 12140          NaN      NaN              NaN             NaN            NaN
# 11812       MySQL   Tableau              NaN             NaN            NaN
#
#       share_GitHub share_Personal blog share_Kaggle share_Colab share_Shiny  \
# index
# 185        GitHub                  NaN      Kaggle       Colab          NaN
# 3645       GitHub                  NaN          NaN         NaN         NaN
# 12140          NaN                 NaN          NaN         NaN         NaN
# 11812      GitHub                  NaN          NaN      Colab          NaN
#
#       share_None share_OTHER courses_Coursera courses_edX  \
# index
# 185          NaN         NaN         Coursera         NaN
# 3645         NaN         NaN         Coursera         NaN
# 12140        NaN         NaN              NaN         NaN
# 11812        NaN         NaN         Coursera         NaN
#
#              courses_Kaggle courses_DataCamp courses_Fastai courses_Udacity  \
# index
# 185    Kaggle Learn Courses         DataCamp        Fast.ai             NaN
# 3645   Kaggle Learn Courses         DataCamp            NaN             NaN
# 12140                   NaN              NaN            NaN             NaN
# 11812                   NaN              NaN            NaN             NaN
#
#       courses_Udemy courses_LinkedIn courses_Cloud-certification  \
# index
# 185           Udemy              NaN                         NaN
# 3645          Udemy              NaN                         NaN
# 12140           NaN              NaN                         NaN
# 11812         Udemy              NaN                         NaN
#
#       courses_University courses_OTHER                       media_Twitter  \
# index
# 185                  NaN           NaN                                 NaN
# 3645                 NaN           NaN  Twitter (data science influencers)
# 12140                NaN           NaN                                 NaN
# 11812                NaN           NaN                                 NaN
#
#       media_Email                     media_Reddit  \
# index
# 185           NaN                              NaN
# 3645          NaN  Reddit (r/machinelearning, etc)
# 12140         NaN                              NaN
# 11812         NaN                              NaN
#
#                           media_Kaggle media_Forums  \
# index
# 185    Kaggle (notebooks, forums, etc)          NaN
# 3645   Kaggle (notebooks, forums, etc)          NaN
# 12140                              NaN          NaN
# 11812  Kaggle (notebooks, forums, etc)          NaN
#
#                                            media_YouTube media_Podcasts  \
# index
# 185    YouTube (Kaggle YouTube, Cloud AI Adventures, ...            NaN
# 3645   YouTube (Kaggle YouTube, Cloud AI Adventures, ...            NaN
# 12140                                                NaN            NaN
# 11812                                                NaN            NaN
#
#                                              media_Blogs  \
# index
# 185    Blogs (Towards Data Science, Analytics Vidhya,...
# 3645   Blogs (Towards Data Science, Analytics Vidhya,...
# 12140                                                NaN
# 11812  Blogs (Towards Data Science, Analytics Vidhya,...
#
#                                            media_Journal media_Slack  \
# index
# 185                                                  NaN         NaN
# 3645   Journal Publications (peer-reviewed journals, ...         NaN
# 12140                                                NaN         NaN
# 11812                                                NaN         NaN
#
#       media_OTHER cat_experience   cat_salary
# index
# 185           NaN            Mid        < 20K
# 3645          NaN        Senior+  100K - 200K
# 12140         NaN            Mid          NaN
# 11812         NaN            Mid        < 20K

# %%
df_da.describe(include='object').T
# Out:
#                count unique  \
# age             3269     11
# gender          3269      5
# country         3269     66
# education       3269      7
# role            3269      2
# ...              ...    ...
# media_Journal    260      1
# media_Slack      258      1
# media_OTHER       82      1
# cat_experience  3269      5
# cat_salary      2924      5
#
#                                                               top  freq
# age                                                         25-29   788
# gender                                                        Man  2538
# country                                                     India   795
# education                                         Master’s degree  1514
# role                                                 Data Analyst  2301
# ...                                                           ...   ...
# media_Journal   Journal Publications (peer-reviewed journals, ...   260
# media_Slack          Slack Communities (ods.ai, kagglenoobs, etc)   258
# media_OTHER                                                 Other    82
# cat_experience                                             Junior  1881
# cat_salary                                                  < 20K  1853
#
# [82 rows x 4 columns]

# %%
df_da.stb.missing()
# Out:
#                      missing  total    percent
# notebook_codeocean      3247   3269  99.327011
# notebook_paperspace     3246   3269  99.296421
# notebook_deepnote       3243   3269  99.204650
# notebook_zeppelin       3241   3269  99.143469
# share_NBViewer          3241   3269  99.143469
# ...                      ...    ...        ...
# role                       0   3269   0.000000
# education                  0   3269   0.000000
# country                    0   3269   0.000000
# cat_experience             0   3269   0.000000
# age                        0   3269   0.000000
#
# [82 rows x 3 columns]

# %%
# creamos diferentes df con datos sociodemográficos propios para cada columna que nos interesa 
# y poder expandirlas sin crear demasiadas filas


sociodemo_language = df_da[["age","gender", "country", "education", "role", "field", "cat_experience", "cat_salary","prog_language"] ]
sociodemo_language["languages"] = sociodemo_language["prog_language"].str.split(",")
df_languages = sociodemo_language.explode(["languages"])
df_languages.drop("prog_language", inplace= True, axis= 1)
df_languages.sample(2)
# Out:
# C:\Users\anais\AppData\Local\Temp\ipykernel_21260\4217408243.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sociodemo_language["languages"] = sociodemo_language["prog_language"].str.split(",")
#          age gender               country        education              role  \
# index
# 7382   25-29  Woman  United Arab Emirates  Master’s degree  Business Analyst
# 17332  30-34    Man                 Japan  Master’s degree  Business Analyst
#
#                            field cat_experience  cat_salary languages
# index
# 7382        Computers/Technology         Senior  50K - 100K    Python
# 17332  Manufacturing/Fabrication         Junior  50K - 100K    Python

# %%
sociodemo_code_env = df_da[["age","gender", "country", "education", "role", "field", "cat_experience", "cat_salary","code_env"] ]
sociodemo_code_env["cod_env"] = sociodemo_code_env["code_env"].str.split(",")
df_code_env = sociodemo_code_env.explode(["cod_env"])
df_code_env.drop("code_env", inplace= True, axis= 1)
df_code_env.sample(2)
# Out:
# C:\Users\anais\AppData\Local\Temp\ipykernel_21260\993416549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sociodemo_code_env["cod_env"] = sociodemo_code_env["code_env"].str.split(",")
#          age gender country          education              role  \
# index
# 24238  30-34    Man   Kenya    Master’s degree      Data Analyst
# 10212  40-44    Man  Mexico  Bachelor’s degree  Business Analyst
#
#                         field cat_experience  cat_salary      cod_env
# index
# 24238      Non-profit/Service            Mid  50K - 100K  JupyterLab
# 10212  Medical/Pharmaceutical            Mid   20K - 50K       Spyder

# %%
sociodemo_viz = df_da[["age","gender", "country", "education", "role", "field", "cat_experience", "cat_salary","viz"] ]
sociodemo_viz["visual"] = sociodemo_viz["viz"].str.split(",")
df_viz = sociodemo_viz.explode(["visual"])
df_viz.drop("viz", inplace= True, axis= 1)
df_viz.sample(2)
# Out:
# C:\Users\anais\AppData\Local\Temp\ipykernel_21260\2257016201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sociodemo_viz["visual"] = sociodemo_viz["viz"].str.split(",")
#          age gender      country          education          role  \
# index
# 17320  25-29    Man  Netherlands    Master’s degree  Data Analyst
# 16644  30-34    Man    Australia  Bachelor’s degree  Data Analyst
#
#                       field cat_experience  cat_salary  \
# index
# 17320                 Other         Senior   20K - 50K
# 16644  Computers/Technology            Mid  50K - 100K
#
#                          visual
# index
# 17320  Plotly / Plotly Express
# 16644                  Seaborn

# %%
#Creamos la función para crear una columna que una las anteriores:
def unir(col):
    lista_valores = []
    for element in col:
        if str(element) != "nan":
            lista_valores.append(str(element))
        else:
            pass
    return lista_valores

# %%
# creamos una lista con todas las columnas relacionadas a la pregunta notebooks

lista_notebooks = ['notebook_kaggle', 'notebook_colab', 'notebook_azure',
       'notebook_paperspace', 'notebook_binder', 'notebook_codeocean',
       'notebook_ibmwatsonstudio', 'notebook_amazonsagemaker',
       'notebook_amazonemr', 'notebook_googlecloudnotebooks',
       'notebook_googleclouddatalab', 'notebook_databricks',
       'notebook_zeppelin', 'notebook_deepnote', 'notebook_observable',
       'notebook_OTHER']

# %%
# aplicamos la función de unir columnas sobre el df completo pero uniendo solo las columnas 'notebooks':
df_da['notebooks_unido'] = df_da[lista_notebooks].apply(unir, axis=1)

# %%
#comprobamos:
df_da.head(2)
# Out:
#          age     gender                   country  \
# index
# 16     50-54        Man                   Belgium
# 32     22-24  Nonbinary  United States of America
#
#                                                education          role  \
# index
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
#
#       prog_language                      code_env    notebook_kaggle  \
# index
# 16      Python, SQL  JupyterLab ,Jupyter Notebook   Kaggle Notebooks
# 32                R                      RStudio                 NaN
#
#         notebook_colab notebook_azure notebook_paperspace notebook_binder  \
# index
# 16     Colab Notebooks            NaN                 NaN             NaN
# 32                 NaN            NaN                 NaN             NaN
#
#       notebook_codeocean notebook_ibmwatsonstudio notebook_amazonsagemaker  \
# index
# 16                   NaN                      NaN                      NaN
# 32                   NaN                      NaN                      NaN
#
#       notebook_amazonemr notebook_googlecloudnotebooks  \
# index
# 16                   NaN                           NaN
# 32                   NaN                           NaN
#
#       notebook_googleclouddatalab                   notebook_databricks  \
# index
# 16                            NaN   Databricks Collaborative Notebooks
# 32           Google Cloud Datalab                                   NaN
#
#       notebook_zeppelin notebook_deepnote notebook_observable notebook_OTHER  \
# index
# 16                  NaN               NaN                 NaN            NaN
# 32                  NaN               NaN                 NaN            NaN
#
#                                                   viz  \
# index
# 16      Matplotlib ,Seaborn ,Plotly / Plotly Express
# 32                                  Ggplot / ggplot2
#
#                            field       salary learn_dp_MySQL  \
# index
# 16                 Energy/Mining  2,000-2,999            NaN
# 32     Manufacturing/Fabrication          NaN            NaN
#
#       learn_dp_PostgreSQL learn_dp_SQLite learn_dp_Oracle learn_dp_Mongo  \
# index
# 16                    NaN             NaN             NaN            NaN
# 32                    NaN             NaN             NaN            NaN
#
#       learn_dp_Snowflake learn_dp_IBMDd2 learn_dp_SQLServer  \
# index
# 16                   NaN             NaN                NaN
# 32                   NaN             NaN                NaN
#
#                    learn_dp_AzureSQL learn_dp_AzureCosmos learn_dp_Redshift  \
# index
# 16     Microsoft Azure SQL Database                   NaN               NaN
# 32                               NaN                  NaN               NaN
#
#       learn_dp_Aurora learn_dp_RDS learn_dp_DynamoDB learn_dp_BigQuery  \
# index
# 16                NaN          NaN               NaN               NaN
# 32                NaN          NaN               NaN               NaN
#
#       learn_dp_CloudSQL learn_dp_Firestore learn_dp_BigTable learn_dp_Spanner  \
# index
# 16                  NaN                NaN               NaN              NaN
# 32                  NaN                NaN               NaN              NaN
#
#       learn_dp_Other dp_most_freq BI_tools share_plotlydash share_streamlit  \
# index
# 16               NaN          NaN      NaN              NaN             NaN
# 32               NaN          NaN      NaN              NaN             NaN
#
#       share_NBViewer share_GitHub share_Personal blog share_Kaggle  \
# index
# 16               NaN          NaN                 NaN          NaN
# 32               NaN          NaN                 NaN          NaN
#
#       share_Colab share_Shiny share_None share_OTHER courses_Coursera  \
# index
# 16            NaN         NaN        NaN         NaN         Coursera
# 32            NaN         NaN        NaN         NaN              NaN
#
#       courses_edX        courses_Kaggle courses_DataCamp courses_Fastai  \
# index
# 16            NaN  Kaggle Learn Courses              NaN            NaN
# 32            NaN                   NaN              NaN            NaN
#
#       courses_Udacity courses_Udemy courses_LinkedIn  \
# index
# 16                NaN           NaN              NaN
# 32                NaN           NaN              NaN
#
#                              courses_Cloud-certification courses_University  \
# index
# 16     Cloud-certification programs (direct from AWS,...                NaN
# 32                                                   NaN                NaN
#
#       courses_OTHER media_Twitter media_Email media_Reddit  \
# index
# 16              NaN           NaN         NaN          NaN
# 32              NaN           NaN         NaN          NaN
#
#                           media_Kaggle media_Forums media_YouTube  \
# index
# 16     Kaggle (notebooks, forums, etc)          NaN           NaN
# 32                                 NaN          NaN           NaN
#
#       media_Podcasts                                        media_Blogs  \
# index
# 16               NaN  Blogs (Towards Data Science, Analytics Vidhya,...
# 32               NaN                                                NaN
#
#       media_Journal media_Slack media_OTHER cat_experience cat_salary  \
# index
# 16              NaN         NaN         NaN        Senior+      < 20K
# 32              NaN         NaN         NaN         Junior        NaN
#
#                                          notebooks_unido
# index
# 16     [ Kaggle Notebooks, Colab Notebooks,  Databric...
# 32                                [Google Cloud Datalab]

# %%
# Nos vamos a quedar solo con las columnas sociodemograficas y la nueva creada:

sociodemo_notebooks = df_da[["age","gender", "country", "education", "role", "field", "cat_experience", "cat_salary","notebooks_unido"]]
df_notebooks = sociodemo_notebooks.explode(["notebooks_unido"])
df_notebooks.head()
# Out:
#          age     gender                   country  \
# index
# 16     50-54        Man                   Belgium
# 16     50-54        Man                   Belgium
# 16     50-54        Man                   Belgium
# 32     22-24  Nonbinary  United States of America
# 33     30-34      Woman                     Egypt
#
#                                                education          role  \
# index
# 16                                     Bachelor’s degree  Data Analyst
# 16                                     Bachelor’s degree  Data Analyst
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
#
#                            field cat_experience cat_salary  \
# index
# 16                 Energy/Mining        Senior+      < 20K
# 16                 Energy/Mining        Senior+      < 20K
# 16                 Energy/Mining        Senior+      < 20K
# 32     Manufacturing/Fabrication         Junior        NaN
# 33            Non-profit/Service            Mid      < 20K
#
#                             notebooks_unido
# index
# 16                         Kaggle Notebooks
# 16                          Colab Notebooks
# 16      Databricks Collaborative Notebooks
# 32                     Google Cloud Datalab
# 33                         Kaggle Notebooks

# %%
# vamos a comprobar si quedan nulos en esta columna (muestra que no haya usado nunca uno de estos notebooks):

df_notebooks['notebooks_unido'].isnull().sum()
# Out:
# 1219

# %%
# vamos a eliminar estas filas (solo queremos saber los notebooks más utilizados):

df_notebooks.dropna(subset= 'notebooks_unido', axis = 0, inplace= True)

# %%
df_notebooks['notebooks_unido'].isnull().sum()
# Out:
# 0

# %%
# vamos a hacer lo mismo con las columnas learn:

col_lear_dp = ['learn_dp_MySQL', 'learn_dp_PostgreSQL', 'learn_dp_SQLite', 'learn_dp_Oracle', 'learn_dp_Mongo', 'learn_dp_Snowflake', 'learn_dp_IBMDd2', 'learn_dp_SQLServer',
'learn_dp_AzureSQL', 'learn_dp_AzureCosmos', 'learn_dp_Redshift', 'learn_dp_Aurora',
'learn_dp_RDS', 'learn_dp_DynamoDB', 'learn_dp_BigQuery', 'learn_dp_CloudSQL', 'learn_dp_Firestore', 'learn_dp_BigTable', 'learn_dp_Spanner', 'learn_dp_Other']

# %%
df_da['learn_unido'] = df_da[col_lear_dp].apply(unir, axis=1)

# %%
sociodemo_learn = df_da[["age","gender", "country", "education", "role", "field", "cat_experience", "cat_salary","learn_unido"]]
df_learn = sociodemo_learn.explode(["learn_unido"])
df_learn.head()
# Out:
#          age     gender                   country  \
# index
# 16     50-54        Man                   Belgium
# 32     22-24  Nonbinary  United States of America
# 33     30-34      Woman                     Egypt
# 33     30-34      Woman                     Egypt
# 33     30-34      Woman                     Egypt
#
#                                                education          role  \
# index
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
#
#                            field cat_experience cat_salary  \
# index
# 16                 Energy/Mining        Senior+      < 20K
# 32     Manufacturing/Fabrication         Junior        NaN
# 33            Non-profit/Service            Mid      < 20K
# 33            Non-profit/Service            Mid      < 20K
# 33            Non-profit/Service            Mid      < 20K
#
#                          learn_unido
# index
# 16     Microsoft Azure SQL Database
# 32                               NaN
# 33                            MySQL
# 33                           SQLite
# 33                          MongoDB

# %%
df_learn['learn_unido'].isnull().sum()
# Out:
# 2134

# %%
df_learn.dropna(subset= 'learn_unido', axis = 0, inplace= True)

# %%
df_learn['learn_unido'].isnull().sum()
# Out:
# 0

# %%
col_share = ['share_plotlydash', 'share_streamlit', 'share_NBViewer', 'share_GitHub', 'share_Personal blog', 'share_Kaggle', 'share_Colab', 'share_Shiny', 'share_None', 'share_OTHER']

# %%
df_da['share_unido'] = df_da[col_share].apply(unir, axis=1)

# %%
sociodemo_share = df_da[["age","gender", "country", "education", "role", "field", "cat_experience", "cat_salary","share_unido"]]
df_share = sociodemo_share.explode(["share_unido"])
df_share.head()
# Out:
#          age     gender                   country  \
# index
# 16     50-54        Man                   Belgium
# 32     22-24  Nonbinary  United States of America
# 33     30-34      Woman                     Egypt
# 46     22-24        Man                     China
# 52     40-44        Man              South Africa
#
#                                                education          role  \
# index
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
# 46     Some college/university study without earning ...  Data Analyst
# 52                                       Master’s degree  Data Analyst
#
#                            field cat_experience cat_salary  \
# index
# 16                 Energy/Mining        Senior+      < 20K
# 32     Manufacturing/Fabrication         Junior        NaN
# 33            Non-profit/Service            Mid      < 20K
# 46          Computers/Technology         Junior      < 20K
# 52     Manufacturing/Fabrication         Junior  20K - 50K
#
#                            share_unido
# index
# 16                                 NaN
# 32                                 NaN
# 33     I do not share my work publicly
# 46                                 NaN
# 52     I do not share my work publicly

# %%
df_share['share_unido'].isnull().sum()
# Out:
# 1610

# %%
df_share.dropna(subset= 'share_unido', axis = 0, inplace= True)

# %%
df_share['share_unido'].isnull().sum()
# Out:
# 0

# %%
col_courses = ['courses_Coursera', 'courses_edX', 'courses_Kaggle', 'courses_DataCamp', 'courses_Fastai', 'courses_Udacity', 'courses_Udemy', 'courses_LinkedIn',
'courses_Cloud-certification', 'courses_University', 'courses_OTHER']

# %%
df_da['courses_unido'] = df_da[col_courses].apply(unir, axis=1)

# %%
sociodemo_courses = df_da[["age","gender", "country", "education", "role", "field", "cat_experience", "cat_salary","courses_unido"]]
df_courses = sociodemo_courses.explode(["courses_unido"])
df_courses.head()
# Out:
#          age     gender                   country  \
# index
# 16     50-54        Man                   Belgium
# 16     50-54        Man                   Belgium
# 16     50-54        Man                   Belgium
# 32     22-24  Nonbinary  United States of America
# 33     30-34      Woman                     Egypt
#
#                                                education          role  \
# index
# 16                                     Bachelor’s degree  Data Analyst
# 16                                     Bachelor’s degree  Data Analyst
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
#
#                            field cat_experience cat_salary  \
# index
# 16                 Energy/Mining        Senior+      < 20K
# 16                 Energy/Mining        Senior+      < 20K
# 16                 Energy/Mining        Senior+      < 20K
# 32     Manufacturing/Fabrication         Junior        NaN
# 33            Non-profit/Service            Mid      < 20K
#
#                                            courses_unido
# index
# 16                                              Coursera
# 16                                  Kaggle Learn Courses
# 16     Cloud-certification programs (direct from AWS,...
# 32                                                   NaN
# 33                                              Coursera

# %%
df_courses['courses_unido'].isnull().sum()
# Out:
# 889

# %%
df_courses.dropna(subset= 'courses_unido', axis = 0, inplace= True)

# %%
df_courses['courses_unido'].isnull().sum()
# Out:
# 0

# %%
col_media = ['media_Twitter', 'media_Email', 'media_Reddit', 'media_Kaggle', 'media_Forums', 'media_YouTube', 'media_Podcasts', 'media_Blogs', 'media_Journal', 'media_Slack', 'media_OTHER']

# %%
df_da['media_unido'] = df_da[col_media].apply(unir, axis=1)

# %%
sociodemo_media = df_da[["age","gender", "country", "education", "role", "field", "cat_experience", "cat_salary","media_unido"]]
df_media = sociodemo_media.explode(["media_unido"])
df_media.head()
# Out:
#          age     gender                   country  \
# index
# 16     50-54        Man                   Belgium
# 16     50-54        Man                   Belgium
# 32     22-24  Nonbinary  United States of America
# 33     30-34      Woman                     Egypt
# 33     30-34      Woman                     Egypt
#
#                                                education          role  \
# index
# 16                                     Bachelor’s degree  Data Analyst
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
#
#                            field cat_experience cat_salary  \
# index
# 16                 Energy/Mining        Senior+      < 20K
# 16                 Energy/Mining        Senior+      < 20K
# 32     Manufacturing/Fabrication         Junior        NaN
# 33            Non-profit/Service            Mid      < 20K
# 33            Non-profit/Service            Mid      < 20K
#
#                                              media_unido
# index
# 16                       Kaggle (notebooks, forums, etc)
# 16     Blogs (Towards Data Science, Analytics Vidhya,...
# 32                                                   NaN
# 33                    Twitter (data science influencers)
# 33     Email newsletters (Data Elixir, O'Reilly Data ...

# %%
df_media['media_unido'].isnull().sum()
# Out:
# 942

# %%
df_media.dropna(subset= 'media_unido', axis = 0, inplace= True)

# %%
df_media['media_unido'].isnull().sum()
# Out:
# 0

# %%
df_languages.to_csv("../data/df_languages.csv")
df_viz.to_csv("../data/df_viz.csv")
df_code_env.to_csv("../data/df_code_env.csv")
df_notebooks.to_csv("../data/df_notebooks.csv")
df_learn.to_csv("../data/df_learn.csv")
df_share.to_csv("../data/df_share.csv")
df_courses.to_csv("../data/df_courses.csv")
df_media.to_csv("../data/df_media.csv")
