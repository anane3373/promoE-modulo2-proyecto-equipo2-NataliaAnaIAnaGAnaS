# %%
import pandas as pd
import os
import re
import xml.etree.ElementTree as ET

# %%
kaggle = pd.read_csv('data/data_remaning_kaggle.csv', sep = ',', index_col = 'index')
kaggle = kaggle.iloc[:,1:]

# %%
kaggle
# Out:
#                                               Q18_Part_1  \
# index
# 0      General purpose image/video tools (PIL, cv2, s...
# 1                                                    NaN
# 2                                                    NaN
# 3      General purpose image/video tools (PIL, cv2, s...
# 4                                                    NaN
# ...                                                  ...
# 25968  General purpose image/video tools (PIL, cv2, s...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
#
#                                               Q18_Part_2  \
# index
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
exported = pd.read_csv('data/exported_db_data.csv', sep = ',', index_col = 'index')
exported
# Out:
#               Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# index
# 0                    NaN  Colab Notebooks        NaN        NaN        NaN
# 1       Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2       Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3                    NaN  Colab Notebooks        NaN        NaN        NaN
# 4                    NaN              NaN        NaN        NaN        NaN
# ...                  ...              ...        ...        ...        ...
# 25968                NaN  Colab Notebooks        NaN        NaN        NaN
# 25969                NaN              NaN        NaN        NaN        NaN
# 25970                NaN              NaN        NaN        NaN        NaN
# 25971                NaN              NaN        NaN        NaN        NaN
# 25972                NaN              NaN        NaN        NaN        NaN
#
# ...

# %%
tree = ET.parse('data/data_xml_clean.xml')
root = tree.getroot()

xml_list = []
for child in root:
    xml_dict = {}
    for subchild in child:
        xml_dict[subchild.tag] = subchild.text
    xml_list.append(xml_dict)

# %%
xml_diccionario
# Out:
# {'level_0': '25972',
#  'index': '25972',
#  'time': '255',
#  'age': '18-21',
#  'gender': 'Man'}

# %%
xml_series = pd.Series(xml_list)

# %%
xml_series
# Out:
# 0        {'level_0': '0', 'index': '0', 'time': '910', ...
# 1        {'level_0': '1', 'index': '1', 'time': '784', ...
# 2        {'level_0': '2', 'index': '2', 'time': '924', ...
# 3        {'level_0': '3', 'index': '3', 'time': '575', ...
# 4        {'level_0': '4', 'index': '4', 'time': '781', ...
#                                ...
# 25968    {'level_0': '25968', 'index': '25968', 'time':...
# 25969    {'level_0': '25969', 'index': '25969', 'time':...
# 25970    {'level_0': '25970', 'index': '25970', 'time':...
# 25971    {'level_0': '25971', 'index': '25971', 'time':...
# 25972    {'level_0': '25972', 'index': '25972', 'time':...
# Length: 25973, dtype: object

# %%
df_xml = pd.DataFrame.from_dict(xml_series)

# %%
df_xml
# Out:
#                                                        0
# 0      {'level_0': '0', 'index': '0', 'time': '910', ...
# 1      {'level_0': '1', 'index': '1', 'time': '784', ...
# 2      {'level_0': '2', 'index': '2', 'time': '924', ...
# 3      {'level_0': '3', 'index': '3', 'time': '575', ...
# 4      {'level_0': '4', 'index': '4', 'time': '781', ...
# ...                                                  ...
# 25968  {'level_0': '25968', 'index': '25968', 'time':...
# 25969  {'level_0': '25969', 'index': '25969', 'time':...
# 25970  {'level_0': '25970', 'index': '25970', 'time':...
# 25971  {'level_0': '25971', 'index': '25971', 'time':...
# 25972  {'level_0': '25972', 'index': '25972', 'time':...
#
# [25973 rows x 1 columns]

# %%
para_limpiar_xml = df_xml[0].apply(pd.Series)

# %%
para_limpiar_xml
# Out:
#       level_0  index  time    age gender
# 0           0      0   910  50-54    Man
# 1           1      1   784  50-54    Man
# 2           2      2   924  22-24    Man
# 3           3      3   575  45-49    Man
# 4           4      4   781  45-49    Man
# ...       ...    ...   ...    ...    ...
# 25968   25968  25968  1756  30-34    Man
# 25969   25969  25969   253  22-24    Man
# 25970   25970  25970   494  50-54    Man
# 25971   25971  25971   277  45-49    Man
# 25972   25972  25972   255  18-21    Man
#
# [25973 rows x 5 columns]

# %%
para_limpiar_xml = para_limpiar_xml.drop(columns =["level_0"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 para_limpiar_xml = para_limpiar_xml.drop(columns =["level_0"])
#       2 para_limpiar_xml
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
# ...

# %%
para_limpiar_xml
# Out:
#        index  time    age gender
# 0          0   910  50-54    Man
# 1          1   784  50-54    Man
# 2          2   924  22-24    Man
# 3          3   575  45-49    Man
# 4          4   781  45-49    Man
# ...      ...   ...    ...    ...
# 25968  25968  1756  30-34    Man
# 25969  25969   253  22-24    Man
# 25970  25970   494  50-54    Man
# 25971  25971   277  45-49    Man
# 25972  25972   255  18-21    Man
#
# [25973 rows x 4 columns]

# %%
para_limpiar_xml.to_csv('data/df_xml.csv')

# %%
xml = pd.read_csv('data/df_xml.csv', sep = ',', index_col = 'index')
xml = xml.iloc[:,1:]

# %%
xml
# Out:
#        time    age gender
# index
# 0       910  50-54    Man
# 1       784  50-54    Man
# 2       924  22-24    Man
# 3       575  45-49    Man
# 4       781  45-49    Man
# ...     ...    ...    ...
# 25968  1756  30-34    Man
# 25969   253  22-24    Man
# 25970   494  50-54    Man
# 25971   277  45-49    Man
# 25972   255  18-21    Man
#
# [25973 rows x 3 columns]
