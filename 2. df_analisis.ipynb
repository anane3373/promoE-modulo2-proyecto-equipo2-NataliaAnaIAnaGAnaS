# %% [markdown]
# Vamos con XML

# %%
import pandas as pd
import numpy as np
import re
import sidetable

# %%
columnas_select = ['time', 'age', 'gender', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7' 'Q20', 'Q25',
       'Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3', 'Q39_Part_4', 'Q39_Part_5',
       'Q39_Part_6', 'Q39_Part_7', 'Q39_Part_8', 'Q39_Part_9', 'Q39_OTHER',
       'Q40_Part_1', 'Q40_Part_2', 'Q40_Part_3', 'Q40_Part_4', 'Q40_Part_5',
       'Q40_Part_6', 'Q40_Part_7', 'Q40_Part_8', 'Q40_Part_9', 'Q40_Part_10',
       'Q40_Part_11', 'Q40_OTHER', 'Q42_Part_1', 'Q42_Part_2', 'Q42_Part_3',
       'Q42_Part_4', 'Q42_Part_5', 'Q42_Part_6', 'Q42_Part_7', 'Q42_Part_8',
       'Q42_Part_9', 'Q42_Part_10', 'Q42_Part_11', 'Q42_OTHER']

# %%
df_uni = pd.read_csv('data/raw_data.csv', index_col = 0)
pd.options.display.max_columns = None
df_uni.head(1)
# Out:
#        time    age gender     Q3                 Q4     Q5          Q6  \
# index
# 0       910  50-54    Man  India  Bachelor’s degree  Other  5-10 years
#
#            Q8       Q11        Q13         Q15                        Q20  \
# index
# 0      Python  A laptop  2-5 times  5-10 years  Manufacturing/Fabrication
#
#                     Q21  Q22                            Q23            Q25  \
# index
# 0      50-249 employees  3-4  No (we do not use ML methods)  25,000-29,999
#
#              Q26  Q33  Q35                                                Q41  \
# index
# 0      $100-$999  NaN  NaN  Local development environments (RStudio, Jupyt...
#
#               Q7            Q9                 Q12  \
# index
# 0      Python, R   Vim / Emacs  Google Cloud TPUs
#
#                                                      Q14  \
# index
# 0       Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                                      Q16  \
# index
# ...

# %%
df_adalab = df_uni[['time', 'age', 'gender', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q9',
       'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 'Q10_Part_5', 'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9', 'Q10_Part_10',
       'Q10_Part_11', 'Q10_Part_12', 'Q10_Part_13', 'Q10_Part_14', 'Q10_Part_15', 'Q10_Part_16', 'Q10_OTHER',
       'Q14', 'Q20', 'Q25',
       'Q32_B_Part_1', 'Q32_B_Part_2', 'Q32_B_Part_3', 'Q32_B_Part_4', 'Q32_B_Part_5',
       'Q32_B_Part_6', 'Q32_B_Part_7', 'Q32_B_Part_8', 'Q32_B_Part_9', 'Q32_B_Part_10',
       'Q32_B_Part_11', 'Q32_B_Part_12', 'Q32_B_Part_13', 'Q32_B_Part_14', 'Q32_B_Part_15',
       'Q32_B_Part_16', 'Q32_B_Part_17', 'Q32_B_Part_18', 'Q32_B_Part_19', 'Q32_B_Part_20', 'Q32_B_OTHER',
       'Q33', 'Q35',
       'Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3', 'Q39_Part_4', 'Q39_Part_5',
       'Q39_Part_6', 'Q39_Part_7', 'Q39_Part_8', 'Q39_Part_9', 'Q39_OTHER',
       'Q40_Part_1', 'Q40_Part_2', 'Q40_Part_3', 'Q40_Part_4', 'Q40_Part_5',
       'Q40_Part_6', 'Q40_Part_7', 'Q40_Part_8', 'Q40_Part_9', 'Q40_Part_10',
       'Q40_Part_11', 'Q40_OTHER', 'Q42_Part_1', 'Q42_Part_2', 'Q42_Part_3',
       'Q42_Part_4', 'Q42_Part_5', 'Q42_Part_6', 'Q42_Part_7', 'Q42_Part_8',
       'Q42_Part_9', 'Q42_Part_10', 'Q42_Part_11', 'Q42_OTHER']]

# %%
df_adalab.head(1)
# Out:
#        time    age gender     Q3                 Q4     Q5          Q6  \
# index
# 0       910  50-54    Man  India  Bachelor’s degree  Other  5-10 years
#
#               Q7            Q9 Q10_Part_1       Q10_Part_2 Q10_Part_3  \
# index
# 0      Python, R   Vim / Emacs        NaN  Colab Notebooks        NaN
#
#       Q10_Part_4 Q10_Part_5 Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9  \
# index
# 0            NaN        NaN        NaN        NaN        NaN        NaN
#
#       Q10_Part_10 Q10_Part_11 Q10_Part_12 Q10_Part_13 Q10_Part_14 Q10_Part_15  \
# index
# 0             NaN         NaN         NaN         NaN         NaN         NaN
#
#        Q10_Part_16 Q10_OTHER  \
# index
# 0              NaN       NaN
#
#                                                      Q14  \
# index
# 0       Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
#
#                              Q20            Q25 Q32_B_Part_1 Q32_B_Part_2  \
# index
# ...

# %%
df_adalab.columns
# Out:
# Index(['time', 'age', 'gender', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q9',
#        'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 'Q10_Part_5',
#        'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9', 'Q10_Part_10',
#        'Q10_Part_11', 'Q10_Part_12', 'Q10_Part_13', 'Q10_Part_14',
#        'Q10_Part_15', 'Q10_Part_16', 'Q10_OTHER', 'Q14', 'Q20', 'Q25',
#        'Q32_B_Part_1', 'Q32_B_Part_2', 'Q32_B_Part_3', 'Q32_B_Part_4',
#        'Q32_B_Part_5', 'Q32_B_Part_6', 'Q32_B_Part_7', 'Q32_B_Part_8',
#        'Q32_B_Part_9', 'Q32_B_Part_10', 'Q32_B_Part_11', 'Q32_B_Part_12',
#        'Q32_B_Part_13', 'Q32_B_Part_14', 'Q32_B_Part_15', 'Q32_B_Part_16',
#        'Q32_B_Part_17', 'Q32_B_Part_18', 'Q32_B_Part_19', 'Q32_B_Part_20',
#        'Q32_B_OTHER', 'Q33', 'Q35', 'Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3',
#        'Q39_Part_4', 'Q39_Part_5', 'Q39_Part_6', 'Q39_Part_7', 'Q39_Part_8',
#        'Q39_Part_9', 'Q39_OTHER', 'Q40_Part_1', 'Q40_Part_2', 'Q40_Part_3',
# ...

# %%
#Vamos a cambiar el nombre de nuestras columnas

columnas_antiguas = ['time', 'age', 'gender', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q9',
       'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 'Q10_Part_5',
       'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9', 'Q10_Part_10',
       'Q10_Part_11', 'Q10_Part_12', 'Q10_Part_13', 'Q10_Part_14',
       'Q10_Part_15', 'Q10_Part_16', 'Q10_OTHER',
       'Q14', 'Q20', 'Q25',
       'Q32_B_Part_1', 'Q32_B_Part_2', 'Q32_B_Part_3', 'Q32_B_Part_4',
       'Q32_B_Part_5', 'Q32_B_Part_6', 'Q32_B_Part_7', 'Q32_B_Part_8',
       'Q32_B_Part_9', 'Q32_B_Part_10', 'Q32_B_Part_11', 'Q32_B_Part_12',
       'Q32_B_Part_13', 'Q32_B_Part_14', 'Q32_B_Part_15', 'Q32_B_Part_16',
       'Q32_B_Part_17', 'Q32_B_Part_18', 'Q32_B_Part_19', 'Q32_B_Part_20', 'Q32_B_OTHER',
       'Q33', 'Q35',
       'Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3', 'Q39_Part_4', 'Q39_Part_5',
       'Q39_Part_6', 'Q39_Part_7', 'Q39_Part_8', 'Q39_Part_9', 'Q39_OTHER',
       'Q40_Part_1', 'Q40_Part_2', 'Q40_Part_3', 'Q40_Part_4', 'Q40_Part_5',
       'Q40_Part_6', 'Q40_Part_7', 'Q40_Part_8', 'Q40_Part_9', 'Q40_Part_10', 'Q40_Part_11', 'Q40_OTHER', 'Q42_Part_1',
       'Q42_Part_2', 'Q42_Part_3', 'Q42_Part_4', 'Q42_Part_5', 'Q42_Part_6',
       'Q42_Part_7', 'Q42_Part_8', 'Q42_Part_9', 'Q42_Part_10', 'Q42_Part_11',
       'Q42_OTHER']

# %%
nuevas_columnas = ['time', 'age', 'gender', 'country', 'education', 'role', 'coding_experience', 'prog_language', 'code_env', 
'notebook_kaggle', 'notebook_colab', 'notebook_azure', 'notebook_paperspace', 'notebook_binder','notebook_codeocean', 'notebook_ibmwatsonstudio',
'notebook_amazonsagemaker', 'notebook_amazonemr', 'notebook_googlecloudnotebooks','notebook_googleclouddatalab', 'notebook_databricks', 'notebook_zeppelin',
'notebook_deepnote','notebook_observable', 'notebook_none', 'notebook_OTHER',
'viz', 'field', 'salary',
'learn_dp_MySQL', 'learn_dp_PostgreSQL', 'learn_dp_SQLite', 'learn_dp_Oracle', 'learn_dp_Mongo', 'learn_dp_Snowflake', 'learn_dp_IBMDd2', 'learn_dp_SQLServer',
'learn_dp_AzureSQL', 'learn_dp_AzureCosmos', 'learn_dp_Redshift', 'learn_dp_Aurora',
'learn_dp_RDS', 'learn_dp_DynamoDB', 'learn_dp_BigQuery', 'learn_dp_CloudSQL', 'learn_dp_Firestore', 'learn_dp_BigTable', 'learn_dp_Spanner', 'learn_dp_none', 'learn_dp_Other',
'dp_most_freq', 'BI_tools',
'share_plotlydash', 'share_streamlit', 'share_NBViewer', 'share_GitHub', 'share_Personal blog', 'share_Kaggle', 'share_Colab', 'share_Shiny', 'share_None', 'share_OTHER',
'courses_Coursera', 'courses_edX', 'courses_Kaggle', 'courses_DataCamp', 'courses_Fastai', 'courses_Udacity', 'courses_Udemy', 'courses_LinkedIn',
'courses_Cloud-certification', 'courses_University', 'courses_None', 'courses_OTHER',
'media_Twitter', 'media_Email', 'media_Reddit', 'media_Kaggle', 'media_Forums',
'media_YouTube', 'media_Podcasts', 'media_Blogs', 'media_Journal', 'media_Slack', 'media_None', 'media_OTHER']

# %%
columnas_ok = dict(zip(columnas_antiguas, nuevas_columnas))

# %%
df_adalab.rename(columns = columnas_ok, inplace = True)
# Out:
# /tmp/ipykernel_19394/2571815011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adalab.rename(columns = columnas_ok, inplace = True)

# %%
df_adalab.head(1)
# Out:
#        time    age gender country          education   role coding_experience  \
# index
# 0       910  50-54    Man   India  Bachelor’s degree  Other        5-10 years
#
#       prog_language      code_env notebook_kaggle   notebook_colab  \
# index
# 0         Python, R   Vim / Emacs             NaN  Colab Notebooks
#
#       notebook_azure notebook_paperspace notebook_binder notebook_codeocean  \
# index
# 0                NaN                 NaN             NaN                NaN
#
#       notebook_ibmwatsonstudio notebook_amazonsagemaker notebook_amazonemr  \
# index
# 0                          NaN                      NaN                NaN
#
#       notebook_googlecloudnotebooks notebook_googleclouddatalab  \
# index
# 0                               NaN                         NaN
#
#       notebook_databricks notebook_zeppelin notebook_deepnote  \
# index
# 0                     NaN               NaN               NaN
#
# ...

# %%
# cambiamos el nombre de uno de los valores para evitar confusiones
# Jupyter (JupyterLab, Jupyter Notebooks, etc)

df_adalab["code_env"] = df_adalab["code_env"].str.replace("Jupyter (JupyterLab, Jupyter Notebooks, etc)", "JupyterLab")
# Out:
# /tmp/ipykernel_19394/2680190049.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adalab["code_env"] = df_adalab["code_env"].str.replace("Jupyter (JupyterLab, Jupyter Notebooks, etc)", "JupyterLab")

# %%
df_adalab["code_env"].value_counts()
# Out:
# code_env
# Jupyter Notebook                                                                                 2341
# Visual Studio Code (VSCode) ,Jupyter Notebook                                                    1412
# Visual Studio Code (VSCode)                                                                       939
# PyCharm ,Jupyter Notebook                                                                         820
# Visual Studio Code (VSCode) ,PyCharm ,Jupyter Notebook                                            554
#                                                                                                  ...
# RStudio ,Visual Studio , Spyder, Vim / Emacs,Jupyter Notebook                                       1
# JupyterLab ,Visual Studio ,Visual Studio Code (VSCode) , Vim / Emacs,MATLAB ,Jupyter Notebook       1
# JupyterLab ,Visual Studio ,PyCharm , Spyder, Notepad++                                              1
# ...

# %%
#miramos los valores nulos de nuestros datos
df_adalab.stb.missing()
# Out:
#                 missing  total     percent
# media_None        25973  25973  100.000000
# learn_dp_none     25973  25973  100.000000
# courses_None      25973  25973  100.000000
# notebook_none     25973  25973  100.000000
# share_NBViewer    25837  25973   99.476379
# ...                 ...    ...         ...
# age                   0  25973    0.000000
# education             0  25973    0.000000
# country               0  25973    0.000000
# gender                0  25973    0.000000
# time                  0  25973    0.000000
#
# [86 rows x 3 columns]

# %%
# Viendo que hay columnas con 100% nulos, vamos a eliminarlas porque no aportan valor:

df_adalab.drop(['media_None', 'learn_dp_none', 'courses_None', 'notebook_none'], axis= 1, inplace= True)
# Out:
# /tmp/ipykernel_19394/229711289.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adalab.drop(['media_None', 'learn_dp_none', 'courses_None', 'notebook_none'], axis= 1, inplace= True)

# %%
df_adalab.stb.missing()
# Out:
#                      missing  total    percent
# share_NBViewer         25837  25973  99.476379
# notebook_observable    25826  25973  99.434028
# notebook_codeocean     25798  25973  99.326223
# notebook_paperspace    25764  25973  99.195318
# notebook_zeppelin      25722  25973  99.033612
# ...                      ...    ...        ...
# education                  0  25973   0.000000
# country                    0  25973   0.000000
# age                        0  25973   0.000000
# gender                     0  25973   0.000000
# time                       0  25973   0.000000
#
# [82 rows x 3 columns]

# %%
#miramos cuantas filas tenemos en total
df_adalab.shape
# Out:
# (25973, 82)

# %%
#miramos cuantas profesiones tenemos y cuántos registros de cada profesion
df_adalab['role'].value_counts()
# Out:
# role
# Student                         6804
# Data Scientist                  3616
# Software Engineer               2449
# Other                           2393
# Data Analyst                    2301
# Currently not employed          1986
# Research Scientist              1538
# Machine Learning Engineer       1499
# Business Analyst                 968
# Program/Project Manager          849
# Data Engineer                    668
# Product Manager                  319
# Statistician                     313
# DBA/Database Engineer            171
# Developer Relations/Advocacy      99
# Name: count, dtype: int64

# %%
#miramos cuales son los rangos de coding_experience. Vamos a reorganizar estas categorías y a darles nombres más comprensibles.
df_adalab['coding_experience'].unique()
# Out:
# array(['5-10 years', '20+ years', '1-3 years', '< 1 years', '3-5 years',
#        '10-20 years', 'I have never written code'], dtype=object)

# %%
def experience(experiencia):
    if experiencia == 'I have never written code':
        return 'Sin experiencia'
    elif experiencia == '< 1 years' or experiencia == '1-3 years':
        return 'Junior'
    elif experiencia == '3-5 years':
        return 'Mid'
    elif  experiencia == '5-10 years':
        return 'Senior'
    elif experiencia == '10-20 years' or experiencia == '20+ years':
        return 'Senior+'

# %%
df_adalab['cat_experience'] = df_adalab['coding_experience'].apply(experience)
df_adalab.head(2)
# Out:
# /tmp/ipykernel_19394/759313687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adalab['cat_experience'] = df_adalab['coding_experience'].apply(experience)
#        time    age gender    country          education  \
# index
# 0       910  50-54    Man      India  Bachelor’s degree
# 1       784  50-54    Man  Indonesia    Master’s degree
#
#                           role coding_experience       prog_language  \
# index
# 0                        Other        5-10 years           Python, R
# 1      Program/Project Manager         20+ years   SQL, C, C++, Java
#
#                           code_env    notebook_kaggle   notebook_colab  \
# index
# 0                      Vim / Emacs                NaN  Colab Notebooks
# ...

# %%
# vamos a investigar la columna time puesto que no nos cuadra mucho el dato:

df_adalab["time"].value_counts()
# Out:
# time
# 484      44
# 394      42
# 509      41
# 571      41
# 481      41
#          ..
# 4142      1
# 3809      1
# 8055      1
# 2979      1
# 40250     1
# Name: count, Length: 4421, dtype: int64

# %%
#Eliminamos las columnas iniciales.

df_adalab.drop(['coding_experience', "time"], axis = 1, inplace = True)
# Out:
# /tmp/ipykernel_19394/2114026026.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_adalab.drop(['coding_experience', "time"], axis = 1, inplace = True)

# %%
df_adalab.to_csv("data/df_adalab_limpio.csv")
